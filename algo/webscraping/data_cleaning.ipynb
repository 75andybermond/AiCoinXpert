# %%
import pyarrow.parquet as pq
import pandas as pd
import os
import re
# remove warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import  parquet file as parquet
parquet = pq.read_table('/workspaces/AICoinXpert/algo/webscraping/results.parquet')
two_euros_parquet = pq.read_table('/workspaces/AICoinXpert/algo/webscraping/two_euros_df.parquet')
# Convert parquet to pandas dataframe
df = parquet.to_pandas()
df_two_euros = two_euros_parquet.to_pandas()

# %%
df_two_euros.describe()
# Out:
#        price                                              title  \
# count    100                                                100
# unique    91                                                100
# top      148  Monaco 2 Euro commémorative 2007 - 25e anniver...
# freq       2                                                  1
#
#                tirage       picture_url
# count             100               100
# unique             72                57
# top     Tirage: 1.500  No picture found
# freq                6                44

# %%
# merge two euros dataframe with the main dataframe
df= pd.concat([df, df_two_euros], ignore_index=True)

# %%
df.head()
# Out:
#   price                     title  \
# 0  1,74   Allemagne 1 Cent 2022 A
# 1  2,51   Allemagne 2 Cent 2022 A
# 2  2,27   Allemagne 5 Cent 2022 A
# 3  2,61  Allemagne 10 Cent 2022 A
# 4  2,24  Allemagne 20 Cent 2022 A
#
#                                               tirage  \
# 0  Tirage: - - - | seulement Brillant Universel d...
# 1                                 Tirage: 42.200.000
# 2                                 Tirage: 27.000.000
# 3                                 Tirage: 19.800.000
# 4                                 Tirage: 26.200.000
#
#                                          picture_url
# 0  https://www.pieces-euro.tv/img02/thumb/Allemag...
# 1  https://www.pieces-euro.tv/img04/thumb/Allemag...
# 2  https://www.pieces-euro.tv/img05/thumb/Allemag...
# 3  https://www.pieces-euro.tv/img01/thumb/Allemag...
# 4  https://www.pieces-euro.tv/img01/thumb/Allemag...

# %%
# basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3862 entries, 0 to 3861
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        3862 non-null   object
#  1   title        3862 non-null   object
#  2   tirage       3862 non-null   object
#  3   picture_url  3862 non-null   object
# dtypes: object(4)
# memory usage: 120.8+ KB

# %%
df.count()
# Out:
# price          3862
# title          3862
# tirage         3862
# picture_url    3862
# dtype: int64

# %%
# check for null values and duplicates
df.isnull().sum(), print(f'duplicates : {df.duplicated().sum()}')
# Out:
# duplicates : 234
# (price          0
#  title          0
#  tirage         0
#  picture_url    0
#  dtype: int64,
#  None)

# %% [markdown]
# ### Pre-treatment

# %%
df['price'] = df['price'].str.replace(',', '.')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df['title'] = df['title'].astype(str)
#df['tirage'] = df['tirage'].astype(float)
#df.set_index('picture_url', inplace=True)

# %% [markdown]
# ## Indexing

# %%
# Read names of image_folder and assign their name as the index of df

path = '/workspaces/AICoinXpert/algo/webscraping/data/image_folder'
# Read the file names in order they are organized 

# Read the file names from the folder without sorting
file_names = sorted(os.listdir(path))

# Create a DataFrame with the file names
data = pd.DataFrame({'file_names': file_names})

# Print the DataFrame
data
# Out:
#                                             file_names
# 0     Allemagne-1-Cent-2002-A-4030-155548458652804.jpg
# 1     Allemagne-1-Cent-2003-A-4130-155548636420650.jpg
# 2     Allemagne-1-Cent-2004-A-4230-146382005395403.jpg
# 3     Allemagne-1-Cent-2005-A-4330-146382019089283.jpg
# 4     Allemagne-1-Cent-2006-A-4430-146382049379369.jpg
# ...                                                ...
# 3508  Vatican-50-Cent-2020-3270400-159807850444196.jpg
# 3509  Vatican-50-Cent-2021-3313350-162401151586155.jpg
# 3510  Vatican-50-Cent-2022-3359750-165673348677571.jpg
# 3511  Vatican-50-Cent-2023-3403350-168506824994730.jpg
# 3512                                       noimage.png
#
# [3513 rows x 1 columns]

# %%
df["country"] = df["title"].str.split().str[0] # extract country of origin
# df["amount"] = df["title"].str.split().str[1] # get the amount of the coin
df['currency'] = df['title'].str.extract(r'(Cent|Euro)') # get currency of the coin
# extract coins amount that are in range from 1 to 60
df['amount'] = df['title'].str.extract(r'(\d{1,2})')

# Extract years between date ranges
df['year'] = df['title'].str.extract(r'\b(\d{4})\b')

# Extract numeric values from the specified column using regex
df["tirage"] = df['tirage'].str.extract(r'(\d{1,3}(?:\.\d{3})*(?:\.\d*)?)', expand=False)
# remove title column
df.drop(columns=['title'], inplace=True)

# %%
# Extract the index from the URL based on the country name and remove everything before the last backslash
df['Index'] = df.apply(lambda row: row['picture_url'].rsplit('/', 1)[-1], axis=1)

# Set the index of the DataFrame
df.set_index('Index', inplace=True)

# drop picture_url column
df.drop(columns=['picture_url'], inplace=True)

# %%
# function to check folder names that match to the index of the dataframe

def check_index_names(df, path_index):
    # Create a new column to store the check result
    df['SameIndex'] = df.index.isin(path_index)
    return df


check_index_names(df, data['file_names'])
# Out:
#                                                      price      tirage  \
# Index
# Allemagne-1-Cent-2022-A-3348000-164938774098273...    1.74         NaN
# Allemagne-2-Cent-2022-A-3348050-164938774641157...    2.51  42.200.000
# Allemagne-5-Cent-2022-A-3348100-164938775264159...    2.27  27.000.000
# Allemagne-10-Cent-2022-A-3348150-16493877575056...    2.61  19.800.000
# Allemagne-20-Cent-2022-A-3348200-16493877617672...    2.24  26.200.000
# ...                                                    ...         ...
# Vatican-2-Euro-commemorative-2007-80e-anniversa...  151.00      85.000
# Pays-Bas-2-Euro-35-ans-du-programme-Erasmus-202...  151.00       2.500
# No picture found                                    150.00      10.000
# Espagne-2-Euro-commemorative-2014-Parc-Gueell-T...  148.00      12.000
# Vatican-2-Euro-commemorative-2007-80e-anniversa...  148.00      15.000
#
#                                                       country currency amount  \
# Index
# Allemagne-1-Cent-2022-A-3348000-164938774098273...  Allemagne     Cent      1
# Allemagne-2-Cent-2022-A-3348050-164938774641157...  Allemagne     Cent      2
# Allemagne-5-Cent-2022-A-3348100-164938775264159...  Allemagne     Cent      5
# Allemagne-10-Cent-2022-A-3348150-16493877575056...  Allemagne     Cent     10
# Allemagne-20-Cent-2022-A-3348200-16493877617672...  Allemagne     Cent     20
# ...                                                       ...      ...    ...
# Vatican-2-Euro-commemorative-2007-80e-anniversa...    Vatican     Euro      2
# Pays-Bas-2-Euro-35-ans-du-programme-Erasmus-202...   Pays-Bas     Euro      2
# No picture found                                       France     Euro      2
# Espagne-2-Euro-commemorative-2014-Parc-Gueell-T...    Espagne     Euro      2
# Vatican-2-Euro-commemorative-2007-80e-anniversa...    Vatican     Euro      2
#
#                                                     year  SameIndex
# Index
# Allemagne-1-Cent-2022-A-3348000-164938774098273...  2022       True
# Allemagne-2-Cent-2022-A-3348050-164938774641157...  2022       True
# Allemagne-5-Cent-2022-A-3348100-164938775264159...  2022       True
# Allemagne-10-Cent-2022-A-3348150-16493877575056...  2022       True
# Allemagne-20-Cent-2022-A-3348200-16493877617672...  2022       True
# ...                                                  ...        ...
# Vatican-2-Euro-commemorative-2007-80e-anniversa...  2007       True
# Pays-Bas-2-Euro-35-ans-du-programme-Erasmus-202...  2022       True
# No picture found                                    2019      False
# Espagne-2-Euro-commemorative-2014-Parc-Gueell-T...  2014       True
# Vatican-2-Euro-commemorative-2007-80e-anniversa...  2007       True
#
# [3862 rows x 7 columns]

# %%
# count how many false in SameIndex column

df['SameIndex'].value_counts()

# display the false values
# Out:
# SameIndex
# True     3801
# False      61
# Name: count, dtype: int64

# %%
df[df['SameIndex'] == False]
# Out:
#                   price  tirage    country currency amount  year  SameIndex
# Index
# No picture found    NaN     NaN  Allemagne     Euro      2  2018      False
# No picture found    NaN     NaN  Allemagne     Euro      2  2015      False
# No picture found    NaN     NaN  Allemagne     Euro      2  2013      False
# No picture found    NaN     NaN  Allemagne     Euro      2  2012      False
# No picture found    NaN     NaN  Allemagne     Euro      2  2009      False
# ...                 ...     ...        ...      ...    ...   ...        ...
# No picture found  163.0  10.000   Portugal     Euro      2  2016      False
# No picture found  160.0  10.000     France     Euro      2  2014      False
# No picture found  160.0  10.000     France     Euro      2  2015      False
# No picture found  152.0   1.500     Monaco     Euro      2  2012      False
# No picture found  150.0  10.000     France     Euro      2  2019      False
#
# [61 rows x 7 columns]

# %%
# display year only 2023 
df[df['year'] == '2023']
# Out:
#                                                      price      tirage  \
# Index
# Croatie-Serie-Euro-Dubrovnik-2023-3388650-16787...   30.03      30.000
# noimage.png                                          34.07       1.000
# Allemagne-1-Cent-2023-A-3390100-168265018226889...    2.25  28.800.000
# Allemagne-2-Cent-2023-A-3390150-168265018554688...    1.84  18.000.000
# Allemagne-5-Cent-2023-A-3390200-168265019061568...    1.67   9.000.000
# ...                                                    ...         ...
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...   24.96       5.000
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...  104.36       5.000
# No picture found                                    535.00      25.000
# No picture found                                    231.00       2.500
# No picture found                                    228.00       2.500
#
#                                                        country currency  \
# Index
# Croatie-Serie-Euro-Dubrovnik-2023-3388650-16787...     Croatie     Euro
# noimage.png                                            Croatie     Euro
# Allemagne-1-Cent-2023-A-3390100-168265018226889...   Allemagne     Cent
# Allemagne-2-Cent-2023-A-3390150-168265018554688...   Allemagne     Cent
# Allemagne-5-Cent-2023-A-3390200-168265019061568...   Allemagne     Cent
# ...                                                        ...      ...
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...   Slovaquie     Euro
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...   Slovaquie     Euro
# No picture found                                        Monaco     Euro
# No picture found                                    Luxembourg     Euro
# No picture found                                    Luxembourg     Euro
#
#                                                    amount  year  SameIndex
# Index
# Croatie-Serie-Euro-Dubrovnik-2023-3388650-16787...     20  2023       True
# noimage.png                                            20  2023       True
# Allemagne-1-Cent-2023-A-3390100-168265018226889...      1  2023       True
# Allemagne-2-Cent-2023-A-3390150-168265018554688...      2  2023       True
# Allemagne-5-Cent-2023-A-3390200-168265019061568...      5  2023       True
# ...                                                   ...   ...        ...
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...      2  2023       True
# Slovaquie-2-Euro-100e-anniversaire-de-la-premie...      2  2023       True
# No picture found                                        2  2023      False
# No picture found                                        2  2023      False
# No picture found                                        2  2023      False
#
# [309 rows x 7 columns]

# %%
# check how many nans in the dataframe

df.isnull().sum()
# Out:
# price         17
# tirage       412
# country        0
# currency      57
# amount        36
# year          38
# SameIndex      0
# dtype: int64

# %%
# Make Index a column named folder_path and reset the index
df.reset_index(inplace=True)
df.rename(columns={'Index': 'folder_path'}, inplace=True)

# %%
df
# Out:
#                                             folder_path   price      tirage  \
# 0     Allemagne-1-Cent-2022-A-3348000-16493877409827...    1.74         NaN
# 1     Allemagne-2-Cent-2022-A-3348050-16493877464115...    2.51  42.200.000
# 2     Allemagne-5-Cent-2022-A-3348100-16493877526415...    2.27  27.000.000
# 3     Allemagne-10-Cent-2022-A-3348150-1649387757505...    2.61  19.800.000
# 4     Allemagne-20-Cent-2022-A-3348200-1649387761767...    2.24  26.200.000
# ...                                                 ...     ...         ...
# 3857  Vatican-2-Euro-commemorative-2007-80e-annivers...  151.00      85.000
# 3858  Pays-Bas-2-Euro-35-ans-du-programme-Erasmus-20...  151.00       2.500
# 3859                                   No picture found  150.00      10.000
# 3860  Espagne-2-Euro-commemorative-2014-Parc-Gueell-...  148.00      12.000
# 3861  Vatican-2-Euro-commemorative-2007-80e-annivers...  148.00      15.000
#
#         country currency amount  year  SameIndex
# 0     Allemagne     Cent      1  2022       True
# 1     Allemagne     Cent      2  2022       True
# 2     Allemagne     Cent      5  2022       True
# 3     Allemagne     Cent     10  2022       True
# 4     Allemagne     Cent     20  2022       True
# ...         ...      ...    ...   ...        ...
# 3857    Vatican     Euro      2  2007       True
# 3858   Pays-Bas     Euro      2  2022       True
# 3859     France     Euro      2  2019      False
# 3860    Espagne     Euro      2  2014       True
# 3861    Vatican     Euro      2  2007       True
#
# [3862 rows x 8 columns]

# %%
# remove the rows that have false in SameIndex column "only 61 rows"
df = df[df['SameIndex']]

# %% [markdown]
# ### Types modification

# %%
df.tirage = df.tirage.str.replace('.', '').astype(float)
df['amount'] = pd.to_numeric(df['amount'], errors='coerce').astype(pd.Int64Dtype())
df['year'] = pd.to_numeric(df['year'], errors='coerce').astype(pd.Int64Dtype())

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum() 
# Count the number of missing values in each column
# Out:
# folder_path      0
# price            0
# tirage         398
# country          0
# currency        57
# amount          36
# year            38
# SameIndex        0
# dtype: int64

# %%
# display the rows that have null values in tirage column
df[df['tirage'].isnull()].head(5)
# Out:
#                                            folder_path  price  tirage  \
# 0    Allemagne-1-Cent-2022-A-3348000-16493877409827...   1.74     NaN
# 6    Allemagne-1-Euro-2022-A-3348300-16493877725905...   8.15     NaN
# 7    Allemagne-2-Euro-2022-A-3348350-16493877782806...  16.19     NaN
# 234   Autriche-1-Cent-2022-3353450-165129007877935.jpg   0.66     NaN
# 235   Autriche-2-Cent-2022-3353500-165129008473282.jpg   0.66     NaN
#
#        country currency  amount  year  SameIndex
# 0    Allemagne     Cent       1  2022       True
# 6    Allemagne     Euro       1  2022       True
# 7    Allemagne     Euro       2  2022       True
# 234   Autriche     Cent       1  2022       True
# 235   Autriche     Cent       2  2022       True

# %%
# function to get the average tirage of coins values per country
def fill_tirage_with_average(df):
    df['tirage'] = pd.to_numeric(df['tirage'], errors='coerce').astype(float)  # Convert 'tirage' column to float and handle NaN values
    
    for country in df['country'].unique():
        mean_tirage = df[df['country'] == country]['tirage'].mean()
        df.loc[(df['country'] == country) & (df['tirage'].isnull()), 'tirage'] = mean_tirage
        
    return df

# use the function to fill the null values in tirage column
df = fill_tirage_with_average(df)

# %%
### Check on currency column / display the rows that have null values in currency column
df[df['currency'].isnull()]
# remove all the rows that have null values in currency column because they are the Kit coins
df = df[df['currency'].notna()]

# %%
# display all rows with nan values in amount column
df[df['year'].isnull()]
# remove all the rows that have null values year column because they are not coins
df = df[df['year'].notna()]

# %%
# remove SameIndex column
df.drop(columns=['SameIndex'], inplace=True)

# %%
# display year under 1900
df[df['year'] < 1950]
# remove all the rows that have year under 1950
df = df[df['year'] > 1950]

# %%
# find all the folderpath with nonimage.png and remove them
df = df[df['folder_path'].str.contains('noimage.png') == False]

# create a column name with the 4 first elements in folder_path separated by '-'
df['coin_name'] = df['folder_path'].apply(lambda x: '-'.join(x.split('-')[:4]))

# %%
# check double values
duplicate = df[df.duplicated(subset=['coin_name', 'year', 'country'], keep=False)].sort_values(by='coin_name')
# display the duplicate rows
duplicate
# Out:
#                                             folder_path  price        tirage  \
# 3294  Allemagne-1-Cent-2023-A-3390100-16826501822688...   2.25  2.880000e+07
# 3528  Allemagne-1-Cent-2023-A-3390100-16826501822688...   2.25  2.880000e+07
# 3300  Allemagne-1-Euro-2023-A-3390400-16826502092701...   6.74  4.597929e+07
# 3534  Allemagne-1-Euro-2023-A-3390400-16826502092701...   6.74  4.597929e+07
# 3297  Allemagne-10-Cent-2023-A-3390250-1682650195894...   2.06  1.840000e+07
# ...                                                 ...    ...           ...
# 3476    Vatican-5-Cent-2023-3403200-168506822546622.jpg   4.23  4.500000e+04
# 3258   Vatican-50-Cent-2005-2800350-145431916990497.jpg  21.85  8.500000e+04
# 3266  Vatican-50-Cent-2005-Sede-Vacante-MMV-2800430-...  32.46  6.000000e+04
# 3479   Vatican-50-Cent-2023-3403350-168506824994730.jpg   5.17  4.500000e+04
# 3713   Vatican-50-Cent-2023-3403350-168506824994730.jpg   5.17  4.500000e+04
#
#         country currency  amount  year               coin_name
# 3294  Allemagne     Cent       1  2023   Allemagne-1-Cent-2023
# 3528  Allemagne     Cent       1  2023   Allemagne-1-Cent-2023
# 3300  Allemagne     Euro       1  2023   Allemagne-1-Euro-2023
# 3534  Allemagne     Euro       1  2023   Allemagne-1-Euro-2023
# 3297  Allemagne     Cent      10  2023  Allemagne-10-Cent-2023
# ...         ...      ...     ...   ...                     ...
# 3476    Vatican     Cent       5  2023     Vatican-5-Cent-2023
# 3258    Vatican     Cent      50  2005    Vatican-50-Cent-2005
# 3266    Vatican     Cent      50  2005    Vatican-50-Cent-2005
# 3479    Vatican     Cent      50  2023    Vatican-50-Cent-2023
# 3713    Vatican     Cent      50  2023    Vatican-50-Cent-2023
#
# [536 rows x 8 columns]

# %%
# keep only one row of the duplicate rows

#keepindex = duplicate.drop_duplicates(subset=['coin_name', 'year', 'country'], keep='first').index

# %%
# display how many coin names are duplicated
duplicate['coin_name'].value_counts()
# Out:
# coin_name
# Allemagne-2-Euro-2023    22
# France-2-Euro-Jeux       12
# Slovaquie-2-Euro-100e     6
# Italie-2-Euro-150e        6
# Pays-Bas-2-Euro           6
#                          ..
# Grece-10-Cent-2002        2
# Grece-10-Cent-2022        2
# Grece-2-Cent-2002         2
# Grece-2-Cent-2022         2
# Vatican-50-Cent-2023      2
# Name: count, Length: 235, dtype: int64

# %%
# Keeping only one example of each coin name and remove the rest
df.drop_duplicates(subset=['coin_name', 'year', 'country'], keep='first', inplace=True)

# %%
df[df.duplicated(subset=['coin_name', 'year', 'country'], keep=False)].sort_values(by='coin_name')
# Out:
# Empty DataFrame
# Columns: [folder_path, price, tirage, country, currency, amount, year, coin_name]
# Index: []

# %%
# save the dataframe to csv file as 'cleaned_data.csv'
df.to_csv('/workspaces/AICoinXpert/algo/webscraping/cleaned_data_casual_list.csv', index=False)
